# %% [markdown]
# # Linear Regression Example

# %% [raw]
# In this project, we will build a multiple linear regression with two independent variables.
# Steps:
# 1) Load the dataset 'OmniPower.csv'
# 2) Create a Linear Regression Model with two independent variables (Price and Promotion), one dependent variable (Sale)
# 3) Provide input values and predict the Sale
# 4) What is the R square value?
# 5) Plot the nessecary to visualise

# %% [markdown]
# ### Importing all the libaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Contruct Dataframe

# %%
df = pd.read_csv('OmniPower.csv')
df.head()
# Out:
#    Sales  Price  Promotion
# 0   4141     59        200
# 1   3842     59        200
# 2   3056     59        200
# 3   3519     59        200
# 4   4226     59        400

# %%
x = df[['Price', 'Promotion']]  #must use double brackets to select df, becuz multiple col
y = df['Sales']

x_train = x
y_train = y

X_train, X_test, y_train, y_test = train_test_split(x_train,y_train, test_size = 0.2, random_state = 42)
print(X_train.head())
print(y_train.head())
# Out:
#     Price  Promotion
# 12     79        200
# 32     99        600
# 9      59        600
# 0      59        200
# 4      59        400
# 12    1916
# 32    3354
# 9     5120
# 0     4141
# 4     4226
# Name: Sales, dtype: int64

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (34, 2)
# (27,)

# %%
model = LinearRegression()
model = model.fit(X_train, y_train)

print(model.intercept_)
print(model.coef_)
# Out:
# 5730.030909336212
# [-54.58053157   3.91694414]

# %% [markdown]
# ### Prediction

# %%
#predicts on test data
y_pred = model.predict(X_train) #x_test and y_pred must be same length

#single value predict
print(model.predict([[50,200]]))
# Out:
# [3784.39315974]
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([2201.5577442 , 2676.72477064, 4859.94603346, 3293.16837561,
#        4076.55720453, 2984.94657312, 2984.94657312, 4076.55720453,
#        2201.5577442 , 4859.94603346, 3293.16837561, 3293.16837561,
#        1893.33594172, 3293.16837561, 1893.33594172, 3768.33540205,
#        1893.33594172, 3768.33540205, 2984.94657312, 1109.94711279,
#        4076.55720453, 3768.33540205, 2676.72477064, 4076.55720453,
#        4859.94603346, 2201.5577442 , 1893.33594172])

# %% [markdown]
# ### Validate

# %%
print(model.score(X_train, y_train))
# Out:
# 0.7537482665837636

# %% [markdown]
# ### R2 score

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_train, y_pred)
print("Test R2_score:", r2)
# Out:
# Test R2_score: 0.7537482665837636

# %% [markdown]
# ### Visualise

# %%
#cant plot 2 features at same time
# predict on training data
plt.scatter(X_train.loc[:,'Price'], y_train)
plt.show()

# %%
import seaborn as sns
sns.pairplot(data=df, height=3)

# %%
plt.scatter(y_train, y_pred)
plt.ylabel('Predicted Sales', fontsize=14)
plt.xlabel('Actual Sales', fontsize=14)
plt.grid(True)
plt.show()
